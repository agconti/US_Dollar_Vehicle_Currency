# %%
from pandas import *
from statsmodels.discrete.discrete_model import MNLogit, Logit
from patsy import dmatrices

# %%
import sys
sys.path.append('/home/agconti/my_dev/github/AGC_KaggleAux/')
import kaggleaux as ka

# %% [markdown]
# This data represents every Italian import from outside of the EU from 2003 to 2010 that is priced in a vehicle currency.  A vehicle currency is a 3rd country's currency used to denominate the price of the traded good and the settlement currency of the transaction.  So for example when a Chinese firm exports to an Italian firm they could choose to use the Euro, the yuan or a 3rd country's currency.  Often this 3rd country's currency is the US Dollar.... but NOT always.
#
#
#
# The research question for this data is to learn why the US Dollar is NOT always the vehicle currency?  Under what circumstances is another currency of denomination chosen?  If not the US Dollar then what currency is being used?  If not the dollar then why, for example, the Japanese Yen instead of the Australian Dollar etc...?
#
#
#
# First things first.  Look over the attached index file.  It has information on the first sheet regarding the each variable (columns) about what they are and on the 2nd sheet there's a country id list (example, United States = 235).  Get used to what's in this data set.  And yes, it's huge about 1 GB!  That means analysis can be computationally cumbersome.  Also, read up on multinomial logit (http://www.ats.ucla.edu/stat/stata/dae/mlogit.htm).  That would probably be a good place, methodologically, to crunch these numbers.

# %% [markdown]
# ### Beginning of Lit Review
# http://www.newyorkfed.org/research/economists/goldberg/Revision_April_24.pdf
# We contrasts a “coalescing” effect, where exporters minimize the movements of their prices
# relative to their competitors’, with incentives to hedge macroeconomic volatility
# and transaction costs. The **key determinants of invoice currency choice are
# industry features and country size, with some role for foreign-exchange bid-ask
# spreads**. The coalescing effect also goes a long way to explaining the well-known
# dominance of the dollar. Trade flows to the United States are predominantly
# invoiced in dollar, as foreign exporters face competition with U.S. firms. The use
# of the dollar in trade flows that do not involve the United States reflects trade in
# homogenous products where firms need to keep their price in line
#
# **Krugman (1980)** argued that once a currency is
# established as the dominant one in a market, a particular firm has no incentive to invoice in an
# alternative currency as this would lead to higher transaction cost and more volatile sales
# because of movements in its price relative to its competitors’. Once a currency has acquired a
# prominent role, it may keep this role even if another currency with similarly low costs emerges.
#
# A third line of argument emphasizes that invoicing currency selection is driven by the
# role of volatility in macroeconomic variables in different countries. Firms have an incentive to
# invoice their trade in the currency of a country where the volatility of shocks, such as those
# arising from monetary aggregates, is moderate, as this will ceteris paribus minimize the
# fluctuations in the exchange rates associated with the currency in questions
#
# ###The dollar as an invoicing currency.
# The first dependent variable examined is the
# share of a country’s exports that are invoiced in dollars,
# $B^e_{$}$ . Explanatory variables include the
# share of the United States as a destination market in country total exports, $X^e_us;^{25}$ the share of a country’s exports that are in homogeneous goods (reference priced plus organized exchange traded), $eλrw$ , both overall and focusing on exports to destinations other than the United States ,
# ( ) 1
# e e
# − ⋅ Xus rw λ . Both variables are also interacted with the size of the exporting country relative
# to the United States (with experimentation on whether using euro area size as a proxy for size
# of countries in the euro area changes results). The variable e
# pipeuro−ust
# reflects the
# differential in transaction costs between the euro and the dollar on the exporter country
# currency, while the dummy variable e
# H$ reflects whether the dollar is preferred over the euro d
# as a hedging currency on country e exports26. Some regressions include a Dollarbloc dummy
# variable, with the dollar bloc countries as Australia, Korea, Malaysia, and Thailand. The
# general specification is:
#
# ![eq](/images/Revision_April_24_dollareq.pdf)
#
# [Krugman 1980 paper](http://www.nber.org/papers/w0333)

# %%
def deltas(b,e):
    return((e-b)/b)

# %%
df = read_csv('ForConti_AllItalianImportsVCP.raw', sep='	')
before_size = df.index.size

# %%
# Get past now deltas
df['xx_delta'] = deltas(df.xx_past, df.xx_now)
df['xm_delta'] = deltas(df.xm_past, df.xm_now)
df['xc_delta'] = deltas(df.xc_past, df.xc_now)
df['xy_delta'] = deltas(df.xy_past, df.xy_now)
df['xdexr_delta'] = deltas(df.xdexr_past, df.xdexr_now)
df['xdint_delta'] = deltas(df.xdint_past, df.xdint_now)
df['xsdinf_delta'] = deltas(df.xsdinf_past, df.xsdinf_now)
df['xinf_delta'] = deltas(df.xinf_past, df.xinf_now)
df['xothr_delta'] = deltas(df.xothr_past, df.xothr_now)
df['xgdppc_delta'] = deltas(df.xgdppc_past, df.xgdppc_now)

# %%
df = df.dropna()

# %%
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 960801 entries, 3 to 1891573
# Data columns (total 97 columns):
# x3yv_E          960801  non-null values
# x3yv_D          960801  non-null values
# x1yv_E          960801  non-null values
# x1yv_D          960801  non-null values
# pctO_PCP        960801  non-null values
# pctO_VCP        960801  non-null values
# pctO_LCP        960801  non-null values
# pctO_USD        960801  non-null values
# pctO_VnD        960801  non-null values
# Obs_Ind         960801  non-null values
# pctV_PCP        960801  non-null values
# pctV_VCP        960801  non-null values
# pctV_LCP        960801  non-null values
# pctV_USD        960801  non-null values
# pctV_VnD        960801  non-null values
# Val_Ind         960801  non-null values
# xx_w            960801  non-null values
# xm_w            960801  non-null values
# mx_w            960801  non-null values
# mm_w            960801  non-null values
# USx_w           960801  non-null values
# USm_w           960801  non-null values
# xporter         960801  non-null values
# mporter         960801  non-null values
# cod             960801  non-null values
# year            960801  non-null values
# bim             960801  non-null values
# exrate          960801  non-null values
# totval          960801  non-null values
# weight          960801  non-null values
# goodid          960801  non-null values
# tran_obs        960801  non-null values
# xdexr_past      960801  non-null values
# xdexr_now       960801  non-null values
# xdint_past      960801  non-null values
# xdint_now       960801  non-null values
# pctEMUxW        960801  non-null values
# pctEMUmW        960801  non-null values
# xx_now          960801  non-null values
# xx_past         960801  non-null values
# xm_now          960801  non-null values
# xm_past         960801  non-null values
# xy_now          960801  non-null values
# xy_past         960801  non-null values
# xc_now          960801  non-null values
# xc_past         960801  non-null values
# CN8_10          960801  non-null values
# sitc4_5         960801  non-null values
# HS07_6          960801  non-null values
# sitc2_5         960801  non-null values
# sitc2_4         960801  non-null values
# herf_x          960801  non-null values
# herf_m          960801  non-null values
# r_homog         960801  non-null values
# r_refp          960801  non-null values
# r_diff          960801  non-null values
# xsdinf_now      960801  non-null values
# xsdinf_past     960801  non-null values
# xinf_now        960801  non-null values
# xinf_past       960801  non-null values
# xothr_now       960801  non-null values
# xothr_past      960801  non-null values
# xgdppc_now      960801  non-null values
# xgdppc_past     960801  non-null values
# PCP             960801  non-null values
# VCP             960801  non-null values
# LCP             960801  non-null values
# USDcp           960801  non-null values
# VCPnUS          960801  non-null values
# x_txrch         960801  non-null values
# x_xphmg         960801  non-null values
# x_xpref         960801  non-null values
# x_xpdif         960801  non-null values
# xpUSD           960801  non-null values
# xpEUR           960801  non-null values
# xpOthr          960801  non-null values
# xfloat          960801  non-null values
# IndExp          960801  non-null values
# IndImp          960801  non-null values
# q1_val          960801  non-null values
# q2_val          960801  non-null values
# q3_val          960801  non-null values
# unitval_calc    960801  non-null values
# q_1_inf         960801  non-null values
# q_3_inf         960801  non-null values
# below_q1_val    960801  non-null values
# above_q3_val    960801  non-null values
# xx_delta        960801  non-null values
# xm_delta        960801  non-null values
# xc_delta        960801  non-null values
# xy_delta        960801  non-null values
# xdexr_delta     960801  non-null values
# xdint_delta     960801  non-null values
# xsdinf_delta    960801  non-null values
# xinf_delta      960801  non-null values
# xothr_delta     960801  non-null values
# xgdppc_delta    960801  non-null values
# dtypes: float64(92), int64(5)

# %%
# show percentage change of obs after dropping obs with NaN values
after_size = df.index.size

change = ((after_size - before_size)/float(before_size))

print before_size, after_size
print change
# Out:
# 1904356 960801
# -0.495471960075

# %% [markdown]
# ###Exploratory Visualizations

# %%
def vol_ploting(df):
    # get the top 10% of trading partners by value count
    top_trading_partners = df.xporter.value_counts()[:int(np.round(df.xporter.value_counts().size * 0.1))]
    # find average of trading vol over each year
    grouped = df.ix[:,['x3yv_E', 'x3yv_D', 'x1yv_E', 'x1yv_D','year','xporter']].groupby(['year','xporter']).mean()
    
    # Setup plotting
    fig = plt.figure(figsize(18,25), dpi=1600)
    
    plot_count = 0 
    for partner in top_trading_partners.index:
        plot_count += 1
        axes = fig.add_subplot(8,3,plot_count, axisbg="#DBDBDB")
        plot_data = grouped.xs(partner, level=1)
        axes.plot(plot_data.index, plot_data)
        axes.grid(axis='x', color='white', linestyle='dashed', lw=1) 
        if plot_count == 1 :
            title('Euro / Dollar Exchange Rate\n Volitlities for trading partner %s' % (int(partner)))
            axes.legend(plot_data.columns, loc='best')
            continue
        title('For trading partner %s' % (int(partner)))
    savefig('images/Exchange_rate_volitlity.png', bbox_inches='tight')

# %%
vol_ploting(df)

# %%
def currency_obsevations_market_share_ploting(df):
    # get the top 10% of trading partners by value count
    top_trading_partners = df.xporter.value_counts()[:int(np.round(df.xporter.value_counts().size * 0.1))]
    # find average of % of industry observations using what pricing over each year
    grouped = df.ix[:,['pctO_PCP', 'pctO_VCP', 'pctO_LCP','pctO_USD','year','xporter']].groupby(['year','xporter']).mean()
    
    # Setup plotting
    fig = plt.figure(figsize(18,25), dpi=1600)
    
    plot_count = 0 
    for partner in top_trading_partners.index:
        plot_count += 1
        axes = fig.add_subplot(8,3,plot_count, axisbg="#DBDBDB")
        plot_data = grouped.xs(partner, level=1)
        axes.plot(plot_data.index, plot_data)
        axes.grid(axis='x', color='white', linestyle='dashed', lw=1) 
        if plot_count == 1 :
            title("Perentage of industry currency usage by obsevations\nfor trading partner %s" % (int(partner)))
            axes.legend(plot_data.columns, loc='best')
            continue
        title('For trading partner %s' % (int(partner)))
    savefig('images/Currency_usage_observations.png', bbox_inches='tight')

# %%
currency_obsevations_market_share_ploting(df)

# %%
def currency_trade_val_market_share_ploting(df):
    # get the top 20 trading partners by value count
    top_trading_partners = df.xporter.value_counts()[:int(np.round(df.xporter.value_counts().size * 0.1))]
    # find average of % of industry observations using what pricing over each year
    grouped = df.ix[:,['pctO_VnD', 'pctV_PCP','pctV_VCP', 'pctV_LCP','pctV_USD','pctV_VnD','year','xporter']].groupby(['year','xporter']).mean()
    
    # Setup plotting
    fig = plt.figure(figsize(18,25), dpi=1600)
    
    plot_count = 0 
    for partner in top_trading_partners.index:
        plot_count += 1
        axes = fig.add_subplot(8,3,plot_count, axisbg="#DBDBDB")
        plot_data = grouped.xs(partner, level=1)
        axes.plot(plot_data.index, plot_data)
        axes.grid(axis='x', color='white', linestyle='dashed', lw=1) 
        if plot_count == 1 :
            title('Perentage of industry currency usage by trade value\nfor trading partner %s' % (int(partner)))
            axes.legend(plot_data.columns, loc='best')
            continue
        title('For trading partner %s' % (int(partner)))
    savefig('images/Currency_usage_trade_value.png', bbox_inches='tight')

# %%
currency_trade_val_market_share_ploting(df)

# %%
def porportion_xm_ploting(df):
    # get the top 10% trading partners by value count
    top_trading_partners = df.xporter.value_counts()[:int(np.round(df.xporter.value_counts().size * 0.1))]
    # find average of % of industry observations using what pricing over each year
    grouped = df.ix[:,['xx_w', 'xm_w', 'mx_w', 'mm_w', 'USx_w', 'USm_w','pctEMUxW', 'pctEMUmW','year','xporter']].groupby(['year','xporter']).mean()
    
    # Setup plotting
    fig = plt.figure(figsize(18,25), dpi=1600)
    
    plot_count = 0 
    for partner in top_trading_partners.index:
        plot_count += 1
        axes = fig.add_subplot(8,3,plot_count, axisbg="#DBDBDB")
        plot_data = grouped.xs(partner, level=1)
        axes.plot(plot_data.index, plot_data)
        axes.grid(axis='x', color='white', linestyle='dashed', lw=1) 
        if plot_count == 1 :
            title('Perentage of imports and exports\nfor trading partner %s' % (int(partner)))
            axes.legend(plot_data.columns, loc='best')
            continue
        title('For trading partner %s' % (int(partner)))
    savefig('images/prop_xm.png', bbox_inches='tight')

# %%
porportion_xm_ploting(df)

# %%
def rate_derive_ploting(df):
    # get the top 10 % of  trading partners by value count
    top_trading_partners = df.xporter.value_counts()[:int(np.round(df.xporter.value_counts().size * 0.1))]
    # find average of % of industry observations using what pricing over each year
    grouped = df.ix[:,['xdexr_past', 'xdexr_now', 'xdint_past', 'xdint_now','year','xporter']].groupby(['year','xporter']).mean()
    
    # Setup plotting
    fig = plt.figure(figsize(18,25), dpi=1600)
    
    plot_count = 0 
    for partner in top_trading_partners.index:
        plot_count += 1
        axes = fig.add_subplot(8,3,plot_count, axisbg="#DBDBDB")
        plot_data = grouped.xs(partner, level=1)
        axes.plot(plot_data.index, plot_data)
        axes.grid(axis='x', color='white', linestyle='dashed', lw=1) 
        if plot_count == 1 :
            title('Rate derivative and interest rate derivative activity\nfor trading partner %s' % (int(partner)))
            axes.legend(plot_data.columns, loc='best')
            continue
        title('For trading partner %s' % (int(partner)))
    savefig('images/rate_derive_activity.png', bbox_inches='tight')

# %%
rate_derive_ploting(df)

# %%
def exporter_trade_health(df):
    # get the top 10 % trading partners by value count
    top_trading_partners = df.xporter.value_counts()[:int(np.round(df.xporter.value_counts().size * 0.1))]
    # find average of % of industry observations using what pricing over each year
    grouped = df.ix[:,['xx_now', 'xx_past', 'xm_now', 'xm_past', 'year', 'xporter']].groupby(['year','xporter']).mean()
    
    # Setup plotting
    fig = plt.figure(figsize(18,25), dpi=1600)
    
    plot_count = 0 
    for partner in top_trading_partners.index:
        plot_count += 1
        axes = fig.add_subplot(8,3,plot_count, axisbg="#DBDBDB")
        plot_data = grouped.xs(partner, level=1)
        axes.plot(plot_data.index, plot_data)
        axes.grid(axis='x', color='white', linestyle='dashed', lw=1) 
        if plot_count == 1 :
            title("Exporter's Trade Health\nfor trading partner %s" % (int(partner)))
            axes.legend(plot_data.columns, loc='best')
            continue
        title('For trading partner %s' % (int(partner)))
    savefig('images/exporter_trade_health.png', bbox_inches='tight')

# %%
exporter_trade_health(df) # change to color  pairs so they are easily read

# %% [markdown]
#     df['trade_health_now'] = df.xx_now -
#
#     # we could look into something like net xports or measueres of country growth / health

# %% [markdown]
# def present_v_past_trade_heath(df):
#     # get the top 10 % trading partners by value count
#     top_trading_partners = df.xporter.value_counts()[:int(np.round(df.xporter.value_counts().size * 0.1))]
#     # find average of % of industry observations using what pricing over each year
#     grouped = df.ix[:,['xx_now', 'xx_past', 'xm_now', 'xm_past', 'xy_now', 'xy_past', 'xc_now', 'xc_past', 'year', 'xporter']].groupby(['year','xporter']).mean()
#
#     # Setup plotting
#     fig = plt.figure(figsize(18,25), dpi=1600)
#
#     plot_count = 0
#     for partner in top_trading_partners.index:
#         plot_count += 1
#         axes = fig.add_subplot(5,4,plot_count, axisbg="#DBDBDB")
#         plot_data = grouped.xs(partner, level=1)
#         axes.plot(plot_data.index, plot_data)
#         axes.grid(axis='x', color='white', linestyle='dashed', lw=1)
#         if plot_count == 1 :
#             title("Exporter's economic strength\nfor trading partner %s" % (int(partner)))
#             axes.legend(plot_data.columns, loc='best')
#             continue
#         title('For trading partner %s' % (int(partner)))
#     savefig('exporter_health_top20.png', bbox_inches='tight')

# %%
def exporter_economic_strength(df):
    # get the top 10 % trading partners by value count
    top_trading_partners = df.xporter.value_counts()[:int(np.round(df.xporter.value_counts().size * 0.1))]
    # find average of % of industry observations using what pricing over each year
    grouped = df.ix[:,['xy_now', 'xc_now','xsdinf_now', 'xinf_now', 'year', 'xporter']].groupby(['year','xporter']).mean()
    
    # Setup plotting
    fig = plt.figure(figsize(18,25), dpi=1600)
    
    plot_count = 0 
    for partner in top_trading_partners.index:
        plot_count += 1
        axes = fig.add_subplot(8,3,plot_count, axisbg="#DBDBDB")
        plot_data = grouped.xs(partner, level=1)
        axes.plot(plot_data.index, plot_data)
        axes.grid(axis='x', color='white', linestyle='dashed', lw=1) 
        if plot_count == 1 :
            title("Exporter's Economic Strength\nfor trading partner %s" % (int(partner)))
            axes.legend(plot_data.columns, loc='best')
            continue
        title('For trading partner %s' % (int(partner)))
    savefig('images/exporter_economic_strength.png', bbox_inches='tight')

# %%
exporter_economic_strength(df)

# %% [markdown]
# ###Regressions:

# %% [markdown]
# Setup basic K-Folds Cross Validation to evaluate models:

# %%
def dataframe_kfolds(df):
    
    import random
    import numpy as np
    obs_to_extract = df.index
    ten_pct_sample = []
    
    # get random 10% subsection of data
    for i in xrange(0, int(round(df.index.size * 0.10))):
        ten_pct_sample.append(random.choice(obs_to_extract))
    
    ninety_pct_sample = np.delete(obs_to_extract, ten_pct_sample) # gives us the complement
    
    return df.ix[ten_pct_sample,:], df.ix[ninety_pct_sample,:]

# %%
df_pred, df = dataframe_kfolds(df)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-20-d2aaee3daae1> in <module>()
# ----> 1 df_pred, df = dataframe_kfolds(df)
#
# <ipython-input-19-026401aa4f62> in dataframe_kfolds(df)
#      12     ninety_pct_sample = np.delete(obs_to_extract, ten_pct_sample) # gives us the complement
#      13
# ---> 14     return df.ix[ten_pct_sample,:], df.ix[ninety_pct_sample,:]
#      15
#
# /usr/lib/python2.7/dist-packages/pandas/pandas/core/indexing.pyc in __getitem__(self, key)
#      45                 pass
#      46
# ---> 47             return self._getitem_tuple(key)
#      48         else:
#      49             return self._getitem_axis(key, axis=0)
#
# /usr/lib/python2.7/dist-packages/pandas/pandas/core/indexing.pyc in _getitem_tuple(self, tup)
#     271                 continue
#     272
# --> 273             retval = getattr(retval,self.name)._getitem_axis(key, axis=i)
#     274
#     275         return retval
#
# /usr/lib/python2.7/dist-packages/pandas/pandas/core/indexing.pyc in _getitem_axis(self, key, axis)
#     398                 raise ValueError('Cannot index with multidimensional key')
#     399
# --> 400             return self._getitem_iterable(key, axis=axis)
#     401         else:
#     402             if com.is_integer(key):
#
# /usr/lib/python2.7/dist-packages/pandas/pandas/core/indexing.pyc in _getitem_iterable(self, key, axis)
#     462                 return _reindex(keyarr, level=level)
#     463             else:
# --> 464                 indexer, missing = labels.get_indexer_non_unique(keyarr)
#     465                 check = indexer != -1
#     466                 result = self.obj.take(indexer[check], axis=axis, convert=False)
#
# /usr/lib/python2.7/dist-packages/pandas/pandas/core/index.pyc in get_indexer_non_unique(self, target, **kwargs)
#     842             tgt_values = target.values
#     843
# --> 844         indexer, missing = self._engine.get_indexer_non_unique(tgt_values)
#     845         return Index(indexer), missing
#     846
#
# /usr/lib/python2.7/dist-packages/pandas/pandas/index.so in pandas.index.IndexEngine.get_indexer_non_unique (pandas/index.c:5275)()
#
# MemoryError:

# %%
ka.columns_to_plus(df)
# Out:
# [x3yv_E + x3yv_D + x1yv_E + x1yv_D + pctO_PCP + pctO_VCP + pctO_LCP + pctO_USD + pctO_VnD + Obs_Ind + pctV_PCP + pctV_VCP + pctV_LCP + pctV_USD + pctV_VnD + Val_Ind + xx_w + xm_w + mx_w + mm_w + USx_w + USm_w + xporter + mporter + cod + year + bim + exrate + totval + weight + goodid + tran_obs + xdexr_past + xdexr_now + xdint_past + xdint_now + pctEMUxW + pctEMUmW + xx_now + xx_past + xm_now + xm_past + xy_now + xy_past + xc_now + xc_past + CN8_10 + sitc4_5 + HS07_6 + sitc2_5 + sitc2_4 + herf_x + herf_m + r_homog + r_refp + r_diff + xsdinf_now + xsdinf_past + xinf_now + xinf_past + xothr_now + xothr_past + xgdppc_now + xgdppc_past + PCP + VCP + LCP + USDcp + VCPnUS + x_txrch + x_xphmg + x_xpref + x_xpdif + xpUSD + xpEUR + xpOthr + xfloat + IndExp + IndImp + q1_val + q2_val + q3_val + unitval_calc + q_1_inf + q_3_inf + below_q1_val + above_q3_val + xx_delta + xm_delta + xc_delta + xy_delta + xdexr_delta + xdint_delta + xsdinf_delta + xinf_delta + xothr_delta + xgdppc_delta]

# %%
results={}           # create a bin to hold the results of all of our models
model_def =[]        # definition of the subspace of the data set relevent to our model; for regression efficency

# %% [markdown]
# Previous variables (past and pct0 obs):

# %%
model_def = ['VCPnUS',
            'xx_now',
            'xx_past',
            'xm_now',
            'xm_past',
            'xy_now',
            'xy_past',
            'xc_now',
            'xc_past',
            'x3yv_E',
            'x3yv_D',
            'x1yv_E',
            'x1yv_D',
            'pctO_PCP',
            'pctO_VCP',
            'pctO_LCP',
            'pctO_USD',
            'pctO_VnD',
            'pctV_PCP',
            'pctV_VCP',
            'pctV_LCP',
            'pctV_USD',
            'pctV_VnD',
            'xdexr_past',
            'xdexr_now',
            'xdint_past',
            'xdint_now',
            'pctEMUxW',
            'pctEMUmW',
            'xsdinf_now',
            'xsdinf_past',
            'xinf_now',
            'xinf_past',
            'x_xphmg',
            'x_xpref',
            'x_xpdif',
            'xgdppc_now',
            'xgdppc_past',]

# %%
formula = '''VCPnUS ~ xx_now + xx_past + xm_now + xm_past + xy_now + xy_past + xc_now + xc_past
            + x3yv_E + x3yv_D + x1yv_E + x1yv_D + pctO_PCP + pctO_VCP + pctO_LCP + pctO_USD + pctO_VnD
            + pctV_PCP + pctV_VCP + pctV_LCP + pctV_USD + pctV_VnD
            + xdexr_past + xdexr_now + xdint_past + xdint_now + pctEMUxW + pctEMUmW
            + xsdinf_now + xsdinf_past + xinf_now + xinf_past + x_xphmg + x_xpref + x_xpdif + xgdppc_now + xgdppc_past'''

# %% [markdown]
# Test Convergence, with simple model:

# %%
y, x = dmatrices('VCPnUS ~ xx_now + xm_now + xy_now + xc_now', data=df.ix[:,model_def], return_type='dataframe')# Prepare dataframe for regression
mod = Logit(y, x)                                                          # Describe model, so it can be fitted  
res1 = mod.fit()                                                           # Fit model

results['basic']=[res1, 'VCPnUS ~ xx_now + xm_now + xy_now + xc_now']                         # save results for later
res1.summary()                                                             # Summarize model
# Out:
# Optimization terminated successfully.
#          Current function value: 112850.171932
#          Iterations 8
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                 VCPnUS   No. Observations:               960801
# Model:                          Logit   Df Residuals:                   960797
# Method:                           MLE   Df Model:                            3
# Date:                Wed, 31 Jul 2013   Pseudo R-squ.:                 0.01215
# Time:                        13:05:43   Log-Likelihood:            -1.1285e+05
# converged:                       True   LL-Null:                   -1.1424e+05
#                                         LLR p-value:                     0.000
# ==============================================================================
#                  coef    std err          z      P>|z|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     -3.6503      0.014   -259.167      0.000        -3.678    -3.623
# xx_now       9.71e-12   2.71e-13     35.796      0.000      9.18e-12  1.02e-11
# xm_now     -9.204e-12   2.88e-13    -31.957      0.000     -9.77e-12 -8.64e-12
# xy_now     -1.052e-12   4.11e-14    -25.610      0.000     -1.13e-12 -9.72e-13
# xc_now      1.113e-12   7.19e-14     15.483      0.000      9.72e-13  1.25e-12
# ==============================================================================
# """

# %% [markdown]
# Previous Model:

# %%
y, x = dmatrices(formula, data=df.ix[:,model_def], return_type='dataframe')# Prepare dataframe for regression
mod = Logit(y, x)                                                          # Describe model, so it can be fitted  
res2 = mod.fit()                                                           # Fit model

results['VCP_now_past']=[res1, formula]                         # save results for later
res2.summary()                                                             # Summarize model
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-15-4aef588d4862> in <module>()
#       1 y, x = dmatrices(formula, data=df.ix[:,model_def], return_type='dataframe')# Prepare dataframe for regression
#       2 mod = Logit(y, x)                                                          # Describe model, so it can be fitted
# ----> 3 res2 = mod.fit()                                                           # Fit model
#       4
#       5 results['VCP_now_past']=[res1, formula]                         # save results for later
#
# /usr/local/lib/python2.7/dist-packages/statsmodels/discrete/discrete_model.pyc in fit(self, start_params, method, maxiter, full_output, disp, callback, **kwargs)
#     280         bnryfit = super(BinaryModel, self).fit(start_params=start_params,
#     281                 method=method, maxiter=maxiter, full_output=full_output,
# --> 282                 disp=disp, callback=callback, **kwargs)
#     283         discretefit = BinaryResults(self, bnryfit)
#     284         return BinaryResultsWrapper(discretefit)
#
# /usr/local/lib/python2.7/dist-packages/statsmodels/discrete/discrete_model.pyc in fit(self, start_params, method, maxiter, full_output, disp, callback, **kwargs)
#     231         mlefit = super(DiscreteModel, self).fit(start_params=start_params,
#     232                 method=method, maxiter=maxiter, full_output=full_output,
# --> 233                 disp=disp, callback=callback, **kwargs)
#     234         return mlefit # up to subclasses to wrap results
#     235
#
# /usr/local/lib/python2.7/dist-packages/statsmodels/base/model.pyc in fit(self, start_params, method, maxiter, full_output, disp, fargs, callback, retall, **kwargs)
#     289                              disp=disp, maxiter=maxiter, callback=callback,
#     290                              retall=retall, full_output=full_output,
# --> 291                              hess=hess)
#     292
#     293         if not full_output:
#
# /usr/local/lib/python2.7/dist-packages/statsmodels/base/model.pyc in _fit_mle_newton(f, score, start_params, fargs, kwargs, disp, maxiter, callback, retall, full_output, hess)
#     339         H = hess(newparams)
#     340         oldparams = newparams
# --> 341         newparams = oldparams - np.dot(np.linalg.inv(H),
#     342                 score(oldparams))
#     343         if retall:
#
# /usr/lib/python2.7/dist-packages/numpy/linalg/linalg.pyc in inv(a)
#     443     """
#     444     a, wrap = _makearray(a)
# --> 445     return wrap(solve(a, identity(a.shape[0], dtype=a.dtype)))
#     446
#     447
#
# /usr/lib/python2.7/dist-packages/numpy/linalg/linalg.pyc in solve(a, b)
#     326     results = lapack_routine(n_eq, n_rhs, a, n_eq, pivots, b, n_eq, 0)
#     327     if results['info'] > 0:
# --> 328         raise LinAlgError('Singular matrix')
#     329     if one_eq:
#     330         return wrap(b.ravel().astype(result_t))
#
# LinAlgError: Singular matrix

# %% [markdown]
# Past and pct0 obs removed:

# %%
model_def = ['VCPnUS',
            'xx_now',
            'xm_now',
            'xy_now',
            'xc_now',
            'x3yv_E',
            'x3yv_D',
            'x1yv_E',
            'x1yv_D',
            'pctV_PCP',
            'pctV_VCP',
            'pctV_LCP',
            'pctV_USD',
            'pctV_VnD',
            'xdexr_now',
            'xdint_now',
            'pctEMUxW',
            'pctEMUmW',
            'xsdinf_now',
            'xinf_now',
            'x_xphmg',
            'x_xpref',
            'x_xpdif',
            'xgdppc_now']

# %%
formula = '''VCPnUS ~ xx_now + xm_now + xy_now + xc_now
            + x3yv_E + x3yv_D + x1yv_E + x1yv_D 
            + pctV_PCP + pctV_VCP + pctV_LCP + pctV_USD + pctV_VnD 
            + xdexr_now + xdint_now + pctEMUxW + pctEMUmW
            + xsdinf_now + xinf_now + x_xphmg + x_xpref + x_xpdif + xgdppc_now'''

# %%
y, x = dmatrices(formula, data=df.ix[:,model_def], return_type='dataframe')# Prepare dataframe for regression
mod = Logit(y, x)                                                          # Describe model, so it can be fitted  
res3 = mod.fit()                                                           # Fit model

results['VCP_now']=[res3, formula]                                         # save results for later
res3.summary()                                                             # Summarize model

# %% [markdown]
# Model with deltas:

# %%
model_def = ['VCPnUS',
            'x3yv_E',
            'x3yv_D',
            'x1yv_E',
            'x1yv_D',
            'pctV_PCP',
            'pctV_VCP',
            'pctV_LCP',
            'pctV_USD',
            'pctV_VnD',
            'pctEMUxW',
            'pctEMUmW',
            'x_xphmg',
            'x_xpref',
            'x_xpdif',
            'xx_delta',
            'xm_delta',
            'xc_delta',
            'xy_delta',
            'xexr_delta',
            'xint_delta',
            'xsin_delta',
            'xin_delta',
            'xothr_delta',
            'xgppc_delta']

# %%
formula = '''VCPnUS ~ x3yv_E + x3yv_D + x1yv_E + x1yv_D 
            + pctV_PCP + pctV_VCP + pctV_LCP + pctV_USD + pctV_VnD
            + pctEMUxW + pctEMUmW
            + x_xphmg + x_xpref + x_xpdif
            + xc_delta + xy_delta + xexr_delta + xint_delta + xsin_delta + xin_delta + xothr_delta + xgppc_delta'''

# %%
y, x = dmatrices(formula, data=df.ix[:,model_def], return_type='dataframe')# Prepare dataframe for regression
mod = Logit(y, x)                                                          # Describe model, so it can be fitted  
res4 = mod.fit()                                                           # Fit model

results['VCP_delta']=[res4, formula]                              # save results for later
res4.summary()                                                             # Summarize model

# %% [markdown]
# Non-Parametric Modeling:

# %% [markdown]
# Add model deltas in:

# %%
model_def = ['VCPnUS',
            'xx_now',
            'xm_now',
            'xy_now',
            'xc_now',
            'x3yv_E',
            'x3yv_D',
            'x1yv_E',
            'x1yv_D',
            'pctV_PCP',
            'pctV_VCP',
            'pctV_LCP',
            'pctV_USD',
            'pctV_VnD',
            'xdexr_now',
            'xdint_now',
            'pctEMUxW',
            'pctEMUmW',
            'xsdinf_now',
            'xinf_now',
            'x_xphmg',
            'x_xpref',
            'x_xpdif',
            'xgdppc_now',
            'xx_delta',
            'xm_delta',
            'xc_delta',
            'xy_delta',
            'xexr_delta',
            'xint_delta',
            'xsin_delta',
            'xin_delta',
            'xothr_delta',
            'xgppc_delta']

# %%
 # sets up a formula thats suitable for ml algos
formula_ml = '''VCPnUS ~ x3yv_E + x3yv_D + x1yv_E + x1yv_D
                + pctO_PCP + pctO_VCP + pctO_LCP + pctO_USD + pctO_VnD + Obs_Ind
                + pctV_PCP + pctV_VCP + pctV_LCP + pctV_USD + pctV_VnD + Val_Ind
                + xx_w + xm_w + mx_w + mm_w + USx_w + USm_w
                + c(xporter) + c(mporter) + C(cod) + C(year)
                + bim + exrate + totval + weight + goodid + tran_obs
                + xdexr_past + xdexr_now + xdint_past + xdint_now + pctEMUxW + pctEMUmW
                + xx_now + xx_past + xm_now + xm_past + xy_now + xy_past + xc_now + xc_past
                + CN8_10 + sitc4_5 + HS07_6 + sitc2_5 + sitc2_4 + herf_x + herf_m + r_homog
                + r_refp + r_diff + xsdinf_now + xsdinf_past + xinf_now + xinf_past + xothr_now + xothr_past
                + xgdppc_now + xgdppc_past + PCP + VCP + LCP + USDcp + x_txrch + x_xphmg + x_xpref + x_xpdif
                + xpUSD + xpEUR + xpOthr + xfloat + IndExp + IndImp + q1_val + q2_val + q3_val + unitval_calc
                + q_1_inf + q_3_inf + below_q1_val + above_q3_val + xc_delta + xy_delta + xexr_delta + xint_delta
                + xsin_delta + xin_delta + xothr_delta + xgppc_delta'''

# %% [markdown]
# Random Forest:

# %%
# import the machine learning library that holds the randomforest
import sklearn.ensemble as ske

# Create the random forest model and fit the model to our training data
y, x = dmatrices(formula_ml, data=df, return_type='dataframe')

#instantiate and fit our model
results_rf = ske.RandomForestClassifier(n_estimators=100, n_jobs=-1).fit(x,y)

# %%
# Score the results -- not cross validated
z = results_rf.score(x,y)
print "Mean accuracy of Random Forest Predictions on the data was: " + str(z)

# %% [markdown]
# ###Version Control

# %% [markdown]
#     !git add US_Dollar_Vehicle_Currency.ipynb
